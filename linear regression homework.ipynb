# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\User'

# %%
pvsw = pd.read_excel("D:\semester 402\ML\pVSw.xls")
pvsw.head()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#        X      Y
# 0   75.1  577.8
# 1   74.3  577.0
# 2   88.7  570.9
# 3  114.6  578.6
# 4   98.5  572.4

# %%
import matplotlib.pyplot as plt
plt.plot(pvsw['X'],pvsw['Y'],label='ploting pressure vs weight')

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
plt.plot(pvsw['X'],pvsw['Y'],label='ploting pressure vs weight')
plt.legend()

# %%
f10 = pvsw.iloc[2:21,:]

# %%
plt.plot(f10['X'],f10['Y'],'ro')
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X= pvsw['X']

# %%
X
# Out:
# 0      75.1
# 1      74.3
# 2      88.7
# 3     114.6
# 4      98.5
# 5     112.0
# 6     114.8
# 7      62.2
# 8     107.0
# 9      90.5
# 10     73.8
# 11    115.8
# 12     99.4
# 13     93.0
# 14     73.9
# 15     65.7
# 16     66.2
# 17     77.9
# 18    109.8
# 19    105.4
# 20     88.6
# 21     89.6
# 22     73.8
# 23    101.3
# 24    120.0
# 25     75.9
# 26     76.2
# 27     81.9
# 28     84.3
# 29     98.0
# Name: X, dtype: float64

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X= pvsw['X']
X= X.values.reshape(-1,1)
Y= pvsw['Y']
Y = Y.values.reshape (-1,1)

# %%
Y
# Out:
# array([[577.8],
#        [577. ],
#        [570.9],
#        [578.6],
#        [572.4],
#        [411.2],
#        [531.7],
#        [563.9],
#        [406.7],
#        [507.1],
#        [496.4],
#        [505.2],
#        [506.4],
#        [510.2],
#        [503.9],
#        [506.2],
#        [506.3],
#        [510.2],
#        [508.6],
#        [510.9],
#        [505.4],
#        [512.8],
#        [502.8],
#        [493. ],
#        [510.8],
#        [512.8],
#        [513.4],
#        [510. ],
#        [504.3],
#        [522. ]])

# %%
X
# Out:
# array([[ 75.1],
#        [ 74.3],
#        [ 88.7],
#        [114.6],
#        [ 98.5],
#        [112. ],
#        [114.8],
#        [ 62.2],
#        [107. ],
#        [ 90.5],
#        [ 73.8],
#        [115.8],
#        [ 99.4],
#        [ 93. ],
#        [ 73.9],
#        [ 65.7],
#        [ 66.2],
#        [ 77.9],
#        [109.8],
#        [105.4],
#        [ 88.6],
#        [ 89.6],
#        [ 73.8],
#        [101.3],
#        [120. ],
#        [ 75.9],
#        [ 76.2],
#        [ 81.9],
#        [ 84.3],
#        [ 98. ]])

# %%
reg = LinearRegression().fit(X, Y)

# %%
reg.score(X, Y)
# Out:
# 0.05420005921419868

# %%
reg.coef_
# Out:
# array([[-0.54186307]])

# %%
reg.intercept_
# Out:
# array([563.87911917])

# %%
reg.predict(np.array([[105.4]]))
# Out:
# array([[506.76675124]])

# %%
import matplotlib.pyplot as plt 
import numpy as np    

def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '--')

# %%
abline(0.54186307, 563.87911917)

# %%
plt.scatter(X, Y, color = "red")

# %%
plt.scatter(X, Y, color = "red")
plt.plot(X, reg.predict(X), color = "green")
plt.show()
